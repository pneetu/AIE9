# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x112de1810>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x112de1d10>
# It’s all the same in that tongue‑twister universe:
#
# > **“A wood‑chuck would chuck as much wood as a wood‑chuck could if a wood‑chuck could chuck wood!”**
#
# That’s the classic punch‑line. (If you really want a number, a 1978 study by wildlife biologist Richard Thomas estimated a burrowing‑chuck might move about **700 cubic feet** of dirt—and if it had a wood‑whacking plan it’d probably pick up a comparable amount of timber.  But the immortal ballad says just as much as it can, if it can.)

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio
sem = asyncio.Semaphore(3)

async def send_request(llm, idx):
  async with sem:
   try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
   except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 4)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 2: In the tongue‑twister spirit, a woodchuck would chuck as muc...
# Response 1: A classic tongue‑twister, but let’s give it a playful, almos...
# Response 3: A woodchuck would chuck as much wood as a woodchuck can—esse...
